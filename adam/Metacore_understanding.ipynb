# %% [markdown]
# # Metacore is the object including metadata for CDISC
# https://github.com/atorus-research/metacore/tree/main
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ADaM

# %% [markdown]
# #### Datasets in ds_spec

# %%
library(metacore)
load(metacore_example("pilot_ADaM.rda"))

# %%
metacore$ds_spec
# Out:
#    dataset
# 1  ADADAS
# 2  ADAE
# 3  ADCIBC
# 4  ADLBC
# 5  ADLBCPV
# 6  ADLBH
# 7  ADLBHPV
# 8  ADLBHY
# 9  ADNPIX
# 10 ADSL
# 11 ADTTE
# 12 ADVS
#    structure
# 1  one record per subject per parameter per analysis visit per analysis date
# 2  one record per subject per adverse event
# 3  one record per subject per parameter per analysis visit per analysis date
# 4  one record per subject per parameter per analysis visit
# 5  one record per subject per parameter per analysis visit
# 6  one record per subject per parameter per analysis visit
# 7  one record per subject per parameter per analysis visit
# 8  one record per subject per parameter per analysis visit
# 9  one record per subject per parameter per analysis visit per analysis date
# 10 one record per subject
# 11 one record per subject per parameter
# 12 one record per subject per parameter per analysis visit per analysis timepoint
#    label
# 1  ADAS-Cog Analysis
# 2  Adverse Events Analysis Dataset
# 3  CIBIC+ Analysis
# ...

# %% [markdown]
# #### ds_vars

# %%
print(paste("The dimension of the dataset is", dim(metacore$ds_vars)))
metacore$ds_vars
# Out:
# [1] "The dimension of the dataset is 509" "The dimension of the dataset is 7"
#     dataset variable key_seq order keep  core supp_flag
# 1   ADADAS  STUDYID  NA       1    FALSE NA   NA
# 2   ADADAS  SITEID   NA       2    FALSE NA   NA
# 3   ADADAS  SITEGR1  NA       3    FALSE NA   NA
# 4   ADADAS  USUBJID   1       4    FALSE NA   NA
# 5   ADADAS  TRTSDT   NA       5    FALSE NA   NA
# 6   ADADAS  TRTEDT   NA       6    FALSE NA   NA
# 7   ADADAS  TRTP     NA       7    FALSE NA   NA
# 8   ADADAS  TRTPN    NA       8    FALSE NA   NA
# 9   ADADAS  AGE      NA       9    FALSE NA   NA
# 10  ADADAS  AGEGR1   NA      10    FALSE NA   NA
# 11  ADADAS  AGEGR1N  NA      11    FALSE NA   NA
# 12  ADADAS  RACE     NA      12    FALSE NA   NA
# 13  ADADAS  RACEN    NA      13    FALSE NA   NA
# 14  ADADAS  SEX      NA      14    FALSE NA   NA
# 15  ADADAS  ITTFL    NA      15    FALSE NA   NA
# 16  ADADAS  EFFFL    NA      16    FALSE NA   NA
# ...

# %%
metacore$var_spec
# Out:
#     variable        type    length label                                 format
# 1   STUDYID         text     12    Study Identifier                      NA
# 2   SITEID          text      3    Study Site Identifier                 NA
# 3   SITEGR1         text      3    Pooled Site Group 1                   NA
# 4   USUBJID         text     11    Unique Subject Identifier             NA
# 5   TRTSDT          integer   8    Date of First Exposure to Treatment   DATE9.
# 6   TRTEDT          integer   8    Date of Last Exposure to Treatment    DATE9.
# 7   TRTP            text     20    Planned Treatment                     NA
# 8   TRTPN           integer   8    Planned Treatment (N)                 NA
# 9   AGE             integer   8    Age                                   NA
# 10  AGEGR1          text      5    Pooled Age Group 1                    NA
# 11  AGEGR1N         integer   8    Pooled Age Group 1 (N)                NA
# ...

# %%
metacore$value_spec
# Out:
#     dataset variable type    sig_dig origin  code_id             where
# 1   ADADAS  STUDYID  text    NA      Derived NA                  NA
# 2   ADADAS  SITEID   text    NA      Derived NA                  NA
# 3   ADADAS  SITEGR1  text    NA      Derived NA                  NA
# 4   ADADAS  USUBJID  text    NA      Derived NA                  NA
# 5   ADADAS  TRTSDT   integer NA      Derived NA                  NA
# 6   ADADAS  TRTEDT   integer NA      Derived NA                  NA
# 7   ADADAS  TRTP     text    NA      Derived CL.ARM              NA
# 8   ADADAS  TRTPN    integer NA      Derived CL.ARMN             NA
# 9   ADADAS  AGE      integer NA      Derived NA                  NA
# 10  ADADAS  AGEGR1   text    NA      Derived CL.AGEGR1           NA
# 11  ADADAS  AGEGR1N  integer NA      Derived CL.AGEGR1N          NA
# 12  ADADAS  RACE     text    NA      Derived CL.RACE             NA
# 13  ADADAS  RACEN    integer NA      Derived CL.RACEN            NA
# ...
